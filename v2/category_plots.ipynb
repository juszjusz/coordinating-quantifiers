# %%
import importlib
import calculator
import domain_objects
import plot_utils

importlib.reload(calculator)
importlib.reload(domain_objects)
importlib.reload(plot_utils)

from calculator import QuotientCalculator, NumericCalculator
from domain_objects import NewCategory

stimuli, calculator = QuotientCalculator.load_from_file()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from bokeh.plotting import figure, show, output_notebook
from plot_utils import bokeh_plot_category


stimulus = stimuli[50]
category = NewCategory.init_from_stimulus(stimulus)
category_pdf = category.discretized_distribution(calculator)

figure = plot_utils.bokeh_plot_category(category, calculator.domain(), category_pdf)

output_notebook()
show(figure)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ef7d452c-4f0c-4b78-992c-1a429882b395">Loading BokehJS ...</span>
#     </div>
#   <div id="e0b71a23-aaf3-4406-aeaf-ccd12298fd8e" data-root-id="p1001" style="display: contents;"></div>

# %%
s1 = 14
s2 = 19
category = NewCategory.init_from_stimuli([(.23, 15)])
category1 = NewCategory.init_from_stimuli([(.5, 22)])
print(category.response(s1, calculator))
print(category1.response(s1, calculator))
# Out:
# 0.03971163681496279
# 0.0006840292121900816

# %%
c= NewCategory.init_from_stimuli([(1, 14)])
c.response(s1, calculator)
# Out:
# 0.2014962764462156

# %%
calculator.pdf()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 calculator.pdf()
#
# TypeError: QuotientCalculator.pdf() missing 1 required positional argument: 'r'
