# %%
import calculator
from bokeh.plotting import figure
from bokeh.plotting import figure, show, output_notebook
import numpy as np
import importlib

# %%
importlib.reload(calculator)
# Out:
# <module 'calculator' from 'C:\\Users\\juszynski\\Desktop\\wspace\\coordinating-quantifiers\\v2\\calculator.py'>

# %%
from calculator import QuotientCalculator,NumericCalculator

# %%
sti_description, calc_description = QuotientCalculator.from_description_with_ans()
sti_file, calc_file = QuotientCalculator.load_from_file_with_ans()
assert sti_description == sti_file
stimuli = sti_description
del sti_description
del sti_file

# %%
def domain_and_pdf(p, calc):
    return calc.domain(), calc.pdf(p)

# %%
p = stimuli[1580]

fig = figure(title='Pdf(X)', x_axis_label='Support', y_axis_label='Pdf(X)')

support, pdf = domain_and_pdf(p, calc_description)
support1, pdf1 = domain_and_pdf(p, calc_file)

zeros = np.where(pdf==0)[0]
zeros = [support[z] for z in zeros]
zeros1 = np.where(pdf1==0)[0]
zeros1 = [support1[z] for z in zeros1]

fig.line(support, pdf, line_width=1, legend_label='Recomputed on fly')
fig.line(support1, pdf1, line_width=1, legend_label='From Franek file', color='pink')
# fig.circle(float(p), -.05, legend_label='Stimuli', color='red', size=2)
# fig.circle(zeros, .1, legend_label='Zeroed', size=1, color='violet')
# fig.circle(zeros1, .05, legend_label='Zeroed1', color='pink',  size=1)

output_notebook()
show(fig)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f1483702-bcd8-41ff-9d88-f3bdcc078038">Loading BokehJS ...</span>
#     </div>
#   <div id="c901756a-807a-4bf9-9c2a-54c7104eb50b" data-root-id="p1083" style="display: contents;"></div>
